# %% [markdown]
# # ME433 - HW2
# Matthew Kim

# %% [markdown]
# ## Questions 1 ~ 4

# %%
import numpy as np 
import pandas as pd 
import csv

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
csv_files = ['sigA.csv','sigB.csv','sigC.csv', 'sigD.csv']

# %%
dfa = pd.read_csv('sigA.csv',  header = None )
dfb = pd.read_csv('sigB.csv',  header = None )
dfc = pd.read_csv('sigC.csv',  header = None )
dfd = pd.read_csv('sigD.csv',  header = None )

# %%
# dfb = 0
# dfc = 0
# dfc = 0
# dfd = 0
# dfs = [dfa,dfb,dfc,dfd]

# %%
# df_list = []
# for i in csv_files :
#     for ii in dfs: 
#         ii = pd.read_csv(i, header = None)
#         df_list.append(ii)

# %%
# x_a = 0
# x_b = 0
# x_c = 0
# x_d = 0
# y_a = 0
# y_b = 0
# y_c = 0
# y_d = 0

# x = [x_a,x_b,x_c,x_d]
# y = [y_a,y_b,y_c,y_d]

# %%
# xl =[]
# yl = []

# for j in df_list:
#     for jj in x:
#         jj = j[0].tolist()
#         xl.append(jj)
#         jjj = j[1].tolist()
#         yl.append(jjj)

# %%
x_a = dfa[0].tolist()
x_b = dfb[0].tolist()
x_c = dfc[0].tolist()
x_d = dfd[0].tolist()

# %%
y_a = dfa[1].tolist()
y_b = dfb[1].tolist()
y_c = dfc[1].tolist()
y_d = dfd[1].tolist()

# %%
plt.plot(x_a,y_a)
plt.title("Sig A")
plt.xlabel("Time")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(x_b,y_b)
plt.title("Sig B")
plt.xlabel("Time")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(x_c,y_c)
plt.title("Sig C")
plt.xlabel("Time")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.plot(x_d,y_d)
plt.title("Sig D")
plt.xlabel("Time")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %%
sample_rate_a = dfa[1].count()/x_a[-1]
sample_rate_b = dfb[1].count()/x_b[-1]
sample_rate_c = dfc[1].count()/x_c[-1]
sample_rate_d = dfd[1].count()/x_d[-1]

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_a # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_b # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_c # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_d # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %% [markdown]
# ## Question 5

# %%
new_ya = []
for i in range(0, len(y_a)): 
    
    avg_val = 0
    sum_val = 0
    for ii in range(0,800):
        try:
            sum_val = sum_val + y_a[i + ii]
        except:
            
            continue
        
    avg_val = sum_val/800
    
    new_ya.append(avg_val)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = new_ya # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_a # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')


plt.show()

# %%
new_yb = []
for i in range(0, len(y_b)): 
    
    avg_val = 0
    sum_val = 0
    for ii in range(0,1500):
        try:
            sum_val = sum_val + y_b[i + ii]
        except:
            
            continue
        
    avg_val = sum_val/1500
    
    new_yb.append(avg_val)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = new_yb # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_b # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')


plt.show()

# %%
new_yc = []
for i in range(0, len(y_c)): 
    
    avg_val = 0
    sum_val = 0
    for ii in range(0,3000):
        try:
            sum_val = sum_val + y_c[i + ii]
        except:
            
            continue
        
    avg_val = sum_val/3000
    
    new_yc.append(avg_val)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = new_yc # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_c # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')


plt.show()

# %%
new_yd = []
for i in range(0, len(y_d)): 
    
    avg_val = 0
    sum_val = 0
    for ii in range(0,1000):
        try:
            sum_val = sum_val + y_d[i + ii]
        except:
            
            continue
        
    avg_val = sum_val/1000
    
    new_yd.append(avg_val)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = new_yd # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_d # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')


plt.show()

# %% [markdown]
# ## Question 6

# %%
new_ya = []

A = 0.999
B = 0.001
na_avg = [1]*len(y_a)
for i in range(1, len(y_a)): 
 
       
        na_avg[i] = A * na_avg[i-1] + B * y_a[i]

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = na_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_a # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample A - A: 0.999 , B: 0.001")
plt.show()

# %%
A = 0.999
B = 0.001
nb_avg = [1]*len(y_b)
for i in range(1, len(y_b)): 
 
       
        nb_avg[i] = A * nb_avg[i-1] + B * y_b[i]

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = nb_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_b # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample B - A: 0.999 , B: 0.001")
plt.show()

# %%
A = 0.995
B = 0.005
nc_avg = [1]*len(y_c)
for i in range(1, len(y_c)): 
 
       
        nc_avg[i] = A * nc_avg[i-1] + B * y_c[i]

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = nc_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_c # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample C - A: 0.995 , B: 0.005")
plt.show()

# %%
A = 0.99
B = 0.01
nd_avg = [1]*len(y_d)
for i in range(1, len(y_d)): 
 
       
        nd_avg[i] = A * nd_avg[i-1] + B * y_d[i]

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = nd_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_d # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample D - A: 0.99 , B: 0.01")
plt.show()

# %% [markdown]
# ## Question 7

# %%
from __future__ import division
 
import numpy as np
 
fc = 0.001 # Cutoff frequency as a fraction of the sampling rate (in (0, 0.5)).
b = 0.001  # Transition band, as a fraction of the sampling rate (in (0, 0.5)).
N = int(np.ceil((4 / b)))
if not N % 2: N += 1  # Make sure that N is odd.
n = np.arange(N)
 
# Compute sinc filter.
h = np.sinc(2 * fc * (n - (N - 1) / 2))
 
# Compute Blackman window.
w = 0.42 - 0.5 * np.cos(2 * np.pi * n / (N - 1)) + \
    0.08 * np.cos(4 * np.pi * n / (N - 1))
 
# Multiply sinc filter by window.
h = h * w
 
# Normalize to get unity gain.
h = h / np.sum(h)

# %%
s = y_a
s = np.convolve(s, h)

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(x_a,s[0:50000])

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = s[0:50000] # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_a
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_a # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_a # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample A - Blackman, Cutoff Freq: 0.001. Transition Band: 0.001")
plt.show()

# %%
from __future__ import division
 
import numpy as np
 
fc = 0.001 # Cutoff frequency as a fraction of the sampling rate (in (0, 0.5)).
b = 0.005  # Transition band, as a fraction of the sampling rate (in (0, 0.5)).
N = int(np.ceil((4 / b)))
if not N % 2: N += 1  # Make sure that N is odd.
n = np.arange(N)
 
# Compute sinc filter.
h = np.sinc(2 * fc * (n - (N - 1) / 2))
 
# Compute Blackman window.
w = 0.42 - 0.5 * np.cos(2 * np.pi * n / (N - 1)) + \
    0.08 * np.cos(4 * np.pi * n / (N - 1))
 
# Multiply sinc filter by window.
h = h * w
 
# Normalize to get unity gain.
h = h / np.sum(h)

# %%
s = y_b
s = np.convolve(s, h)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = s[0:16500] # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_b
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_b # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_b # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample B - Blackman, Cutoff Freq: 0.001. Transition Band: 0.005")
plt.show()

# %%
from __future__ import division
 
import numpy as np
 
fc = 0.1 # Cutoff frequency as a fraction of the sampling rate (in (0, 0.5)).
b = 0.5  # Transition band, as a fraction of the sampling rate (in (0, 0.5)).
N = int(np.ceil((4 / b)))
if not N % 2: N += 1  # Make sure that N is odd.
n = np.arange(N)
 
# Compute sinc filter.
h = np.sinc(2 * fc * (n - (N - 1) / 2))
 
# Compute Blackman window.
w = 0.42 - 0.5 * np.cos(2 * np.pi * n / (N - 1)) + \
    0.08 * np.cos(4 * np.pi * n / (N - 1))
 
# Multiply sinc filter by window.
h = h * w
 
# Normalize to get unity gain.
h = h / np.sum(h)

# %%
s = y_c
s = np.convolve(s, h)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = nc_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_c
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_c # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_c # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample C - Blackman, Cutoff Freq: 0.01. Transition Band: 0.5")
plt.show()

# %%
from __future__ import division
 
import numpy as np
 
fc = 0.001 # Cutoff frequency as a fraction of the sampling rate (in (0, 0.5)).
b = 0.05  # Transition band, as a fraction of the sampling rate (in (0, 0.5)).
N = int(np.ceil((4 / b)))
if not N % 2: N += 1  # Make sure that N is odd.
n = np.arange(N)
 
# Compute sinc filter.
h = np.sinc(2 * fc * (n - (N - 1) / 2))
 
# Compute Blackman window.
w = 0.42 - 0.5 * np.cos(2 * np.pi * n / (N - 1)) + \
    0.08 * np.cos(4 * np.pi * n / (N - 1))
 
# Multiply sinc filter by window.
h = h * w
 
# Normalize to get unity gain.
h = h / np.sum(h)

# %%
s = y_d
s = np.convolve(s, h)

# %%
dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = nd_avg # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, axs = plt.subplots(2, 2, figsize = (15,10))
axs[0,0].plot(t,y,'r')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Amplitude')
axs[1,0].loglog(frq,abs(Y),'r') # plotting the fft
axs[1,0].set_xlabel('Freq (Hz)')
axs[1,0].set_ylabel('|Y(freq)|')




dt = 1.0/10000.0 # 10kHz
# t = np.arange(0.0, 1.0, dt) # 10s
t = x_d
# a constant plus 100Hz and 1000Hz
#s = 4.0 * np.sin(2 * np.pi * 100 * t) + 0.25 * np.sin(2 * np.pi * 1000 * t) + 25

Fs = sample_rate_d # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = y_d # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

axs[0,1].plot(t,y,'black')
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Amplitude')
axs[1,1].loglog(frq,abs(Y),'black') # plotting the fft
axs[1,1].set_xlabel('Freq (Hz)')
axs[1,1].set_ylabel('|Y(freq)|')

fig.suptitle("Sample D - Blackman, Cutoff Freq: 0.01. Transition Band: 0.05")
plt.show()
